# %%
pip install uvicorn
# Out:
# Collecting uvicorn
#   Using cached uvicorn-0.42.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: click>=7.0 in .\.venv\Lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in .\.venv\Lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Using cached uvicorn-0.42.0-py3-none-any.whl (68 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.42.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import datetime as dt
from tabpfn import TabPFNRegressor
from tabpfn.model_loading import (
    load_fitted_tabpfn_model,
    save_fitted_tabpfn_model,
)

# %%
data = pd.read_csv('E:/tabular/proc1.csv')
X = data['X']
X.to_csv('val_x.csv', index=False)

# %%
data = pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv')
data.head()
# Out:
#          Date   Open   High    Low  Close   Volume  Name
# 0  2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN
# 1  2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN
# 2  2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN
# 3  2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN
# 4  2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN

# %%
X = data.drop(['Date', 'Name', 'Volume'], axis=1)
y = data['Volume']

# %%
reg = TabPFNRegressor(device='cuda')

# %%
reg.fit(X, y)
# Out:
# TabPFNRegressor(device='cuda')

# %%
pip freeze -> requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
